# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np


data = pd.read_csv('data.csv')
display(data.head())
# print("\n--------------------------------------\n")
# data_by_artist = pd.read_csv('data_by_artist.csv')
# display(data_by_artist.head())
# print("\n--------------------------------------\n")
# data_by_genres = pd.read_csv('data_by_genres.csv')
# display(data_by_genres.head())
# print("\n--------------------------------------\n")
# data_by_year = pd.read_csv('data_by_year.csv')
# display(data_by_year.head())
# print("\n--------------------------------------\n")
# data_w_genres = pd.read_csv('data_w_genres.csv')
# display(data_w_genres.head())

print("data before: ", len(data), " after: ",end='')
data.dropna()
print(len(data))
# print("data_by_artist before: ", len(data_by_artist), " after: ",end='')
# data_by_artist.dropna()
# print(len(data_by_artist))
# print("data_by_genres before: ", len(data_by_genres), " after: ",end='')
# data_by_genres.dropna()
# print(len(data_by_genres))
# print("data_by_year before: ", len(data_by_year), " after: ",end='')
# data_by_year.dropna()
# print(len(data_by_year))
# print("data_w_genres before: ", len(data_w_genres), " after: ",end='')
# data_w_genres.dropna()
# print(len(data_w_genres))


# zero nan values was found
# count = 0
# for i in range(len(data)):
#   for j in range(len(data.loc[0])):
#     temp = data.iloc[i][j]
#     if(not isinstance(temp, str) and not isinstance(temp, int) and not isinstance(temp, float) and np.isnan(temp)):
#       count += 1
# print('found this many nan feature values: ', count)

###########################
# columns = ['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo', 'valence', 'year']

# data = data[columns]

# display(data.head())
###########################


# dict_data = {}
# for c in columns:
#     min_x = float("inf")
#     max_x = float("-inf")
#     for d in data[c]:
#         min_x = min(min_x, d)
#         max_x = max(max_x, d)
#     dict_data[c] = (min_x, max_x)
#     if(c == 'duration_ms'):
#         print("duration_min max = ", max_x/60000, "and min = ", min_x/60000)




data = data.loc[(data['duration_ms'] <= 720000) & (data['duration_ms'] >=60000)] # 1 min and 12 min
print("new length after removal: ", len(data))
display(data.head())
# data.to_csv('data_new_range.csv', index=False)


# print("cut in half")
# data = data[:(n//2)]
# print("len now: ", len(data))


# print("started")
# for c_i in columns:
#     for c_j in columns:
#         if(c_i != c_j):
#             m = [c_i, c_j]
#             tempx = data[m]
#             tempCov = np.cov(tempx)
#             print(tempCov)
#             print(c_i," and ",c_j, " have cov = ", tempCov)

# print("finished")
# # covMatrix = np.cov(data,bias=True)
# # print(covMatrix)

# col_norm = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']

# data_norm = data.copy(deep=True) # deep copy

# for col in col_norm:
#     for i, val in enumerate(data_norm[col]):
#         data_norm[col].iloc[i] = val*100


# from scipy.stats import pearsonr

# s = set()
# for c_i in columns:
#     for c_j in columns:
#         temp1 = c_i + c_j
#         temp2 = c_j + c_i
#         if(c_i != c_j and temp1 not in s and temp2 not in s):
#             s.add(temp1)
#             s.add(temp2)
#             x = data_norm[c_i]
#             y = data_norm[c_j]
#             corr, _ = pearsonr(x, y)
#             if(corr >= 0.5 or corr <= -0.5):
#                 print("STRONG on ",c_i," and ", c_j)
#             else if(corr <= 0.3 and corr >= -0.3):
#                 print("WEAK on ",c_i," and ", c_j)
#             else:
#                 print("In between ", c_i," and ", c_j)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b989153dde45> in <module>
#       1 import pandas as pd
# ----> 2 import seaborn as sn
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


data = pd.read_csv('data_new_range.csv')
display(data[-5:])
# Out:
#         acousticness                             artists  danceability  \
# 170386       0.00917  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 170387       0.79500                    ['Alessia Cara']         0.429
# 170388       0.80600                       ['Roger Fly']         0.671
# 170389       0.92000                    ['Taylor Swift']         0.462
# 170390       0.23900                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# 170386       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 170387       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 170388       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 170389       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 170390       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode                name  \
# 170386           0.00006    6     0.178    -5.089     0             The One
# ...

# %%
columns = data.columns
strLength = "Total length of rows in data: %d" % (len(data))
d = dict()
for col in columns:
    s = set()
    i = 0
    print("\n--------------------------\nNew column: %s"%(col))
    print("first 3 values:")
    for val in data[col]:
        if val not in s:
            s.add(val)
        if(i < 3):
            print(val)
        i += 1
    d[col] = len(s)
    print("# of Unique Values: ", d[col])
    print(strLength)
# Out:
# --------------------------
# New column: acousticness
# first 3 values:
# 0.991
# 0.643
# 0.993
# # of Unique Values:  4839
# Total length of rows in data: 170391
#
# --------------------------
# New column: artists
# first 3 values:
# ['Mamie Smith']
# ["Screamin' Jay Hawkins"]
# ['Mamie Smith']
# # of Unique Values:  35517
# Total length of rows in data: 170391
#
# --------------------------
# New column: danceability
# first 3 values:
# 0.598
# 0.852
# 0.647
# # of Unique Values:  1223
# Total length of rows in data: 170391
#
# --------------------------
# New column: duration_ms
# first 3 values:
# 168333
# 150200
# 163827
# # of Unique Values:  53186
# Total length of rows in data: 170391
#
# --------------------------
# New column: energy
# first 3 values:
# 0.2239999999999999
# 0.517
# 0.18600000000000003
# # of Unique Values:  2269
# Total length of rows in data: 170391
#
# --------------------------
# New column: explicit
# first 3 values:
# 0
# 0
# 0
# ...

# %%
import matplotlib.pyplot as plt

validCols = list(data.columns)
validCols.remove('artists')
validCols.remove('id')
validCols.remove('name')
validCols.remove('release_date')
print(validCols)
for col in validCols:
    try:
        plt.clf()
        print("\n-------------------")
        print("Feature: %s"%(col))
        h = data[col].hist()
        plt.show(h)
    except Exception:
        print("Invalid col input: %s"%(col))
        print("-------------------")
# col_i = columns[8]
# print("Feature: %s"%(col_i))
# data[col_i].hist()
# Out:
# ['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo', 'valence', 'year']
#
# -------------------
# Feature: acousticness
# -------------------
# Feature: danceability
# -------------------
# Feature: duration_ms
# -------------------
# Feature: energy
# -------------------
# Feature: explicit
# -------------------
# Feature: instrumentalness
# -------------------
# Feature: key
# -------------------
# Feature: liveness
# -------------------
# Feature: loudness
# -------------------
# Feature: mode
# -------------------
# Feature: popularity
# -------------------
# Feature: speechiness
# -------------------
# Feature: tempo
# -------------------
# Feature: valence
# -------------------
# Feature: year

# %%
validCols = list(data.columns)
validCols.remove('id')
validCols.remove('release_date')
new_data = data[validCols].copy()
new_data.to_csv('data_new_range.csv', index=False)
new_data.to_csv('data_new_range.csv.zip', index=False, compression="zip")

# %%
extracs = ["duration_ms", "key","popularity","tempo"]
for i,col in enumerate(extracs):
    max_val = max(new_data[col])
    for j,val in enumerate(new_data[col]):
        new_data[col].iloc[j] /= max_val
    print("New max val for ", col, " is : ", max(new_data[col]))
special = "loudness" # this one has both negative and positive extremes
max_spec = max(new_data[special])
min_spec = abs(min(new_data[special])) # absolute value of min
for i,val in enumerate(new_data[special]):
    if(val >= 0):
        new_data[special].iloc[i] /= max_spec
    else:
        new_data[special].iloc[i] /= min_spec
display(new_data.head())
new_data.to_csv("data_range_norm",index=False)
