# %%
import pandas as pd

# this is data where the genres have been cleaned
users_info = pd.read_csv('postprocessed_user_info_with_genre.csv.zip', compression='zip', index_col=0)
print(users_info.head())
# print(users_info.columns)
print('\n\ndone importing...')
# Out:
# done importing..

# %%
# time to make a threshold to eliminate several containers
from collections import Counter

a = list(users_info['genre'].copy())
letter_counts = Counter(a)
print('shape of users_info before: ', users_info.shape)
print('unique genres before removal: ',len(list(letter_counts)))
delete = set()
for key in letter_counts:
    if(letter_counts[key] < 1000):
        delete.add(key)
for key in delete:
    del letter_counts[key]

# delete the genres with small frequency
indexes = []
for i,g in enumerate(users_info['genre']):
    if(g in delete):
        indexes.append(i)
users_info.drop(users_info.index[indexes], axis=0, inplace=True)
print('-----------------------------')
print('unique genres after removal: ',len(list(letter_counts)))
print('shape of users_info after key removal: ', users_info.shape)
print('length of users_info after: ',sum(letter_counts.values()))
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='area',rot=90)
# Out:
# shape of users_info before:  (893909, 11)
# unique genres before removal:  3115
# -----------------------------
# shape of users_info after key removal:  (646206, 11)
# length of users_info after:  646206
# <AxesSubplot:>

# %%
# stats
s = [(key,val) for key,val in letter_counts.items()]
s.sort(key=lambda x: x[1])
print('min: ', s[0])
print('mean:', sum(letter_counts.values())/len(letter_counts))
print('median: ', s[len(s)//2])
t = Counter(letter_counts.values())
m = -1
mTuple = []
# highest frequency
for k,v in t.items():
    if(v > m):
        m = v
        mTuple = [(k,v)]
    elif(v == m):
        mTuple.append((k,v))
print('mode: %d with freq. of %d'%(mTuple[0][0], mTuple[0][1]))
print('max: ', s[-1])
# Out:
# min:  ('acoustic blues', 1008)
# mean: 4089.9113924050635
# median:  ('funk', 2080)
# mode: 1509 with freq. of 2
# max:  ('dance pop', 70354)

# %%
firstQuartile = s[round(0.25*len(s))][1]
print(firstQuartile)
thirdQuartile = s[round(0.75*len(s))][1]
print(thirdQuartile)
IQR = thirdQuartile - firstQuartile
lowerBound = firstQuartile - 1.5*IQR
upperBound = thirdQuartile + 1.5*IQR
print(lowerBound)
print(upperBound)
outliers = []
for k,v in s:
    if(v > upperBound or v < lowerBound):
        outliers.append((k,v))
print('Number of outliers: ', len(outliers))
print('Number of Inbound numbers:', len(letter_counts)-len(outliers))
print('Outliers:\n',outliers)
# Out:
# 1397
# 4111
# -2674.0
# 8182.0
# Number of outliers:  19
# Number of Inbound numbers: 139
# Outliers:
#  [('alternative dance', 8991), ('latin', 9147), ('alternative hip hop', 9713), ('big room', 9832), ('hip hop', 10616), ('ccm', 11040), ('anthem worship', 11161), ('alternative rock', 11957), ('atl hip hop', 12307), ('alternative metal', 12924), ('edm', 13520), ('pop', 14058), ('alt z', 15451), ('alternative r&b', 15571), ('adult standards', 15923), ('album rock', 17422), ('christian hip hop', 17557), ('chillhop', 17951), ('dance pop', 70354)]

# %%
import matplotlib.pyplot as plt
data = list(letter_counts.values())
data.pop(data.index(70354)) # remove huge outlier called 'dance pop'
plt.boxplot(data,vert=False)
plt.tight_layout()
plt.show()

# %%
data = {} # key=genre, value=dataframe with that genre


print(type(users_info))
print(len(users_info))
for j in range(len(users_info)):
    row = users_info.iloc[j,:].copy()
    if(row['genre'] in letter_counts and row['genre'] not in data):
        data[row['genre']] = [row.tolist()]
    elif(row['genre'] in letter_counts and row['genre'] in data):
        data[row['genre']].append(row.tolist())

keys = list(data.keys())
for key in keys: # turn them all into dataframes
    data[key] = pd.DataFrame(data[key], columns=list(users_info.columns))
for key in keys[:5]: # print info of the first five
    print('genre-type: ',data[key]['genre'][0],' and length: ', len(data[key]['genre']),'\n',data[key].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 646206
# genre-type:  k-pop  and length:  2535
#                       user_id      artist  genre  ...  loudness  speechiness    tempo
# 0  4ura3429lz6lq6xs5itaoqiyi     HINAPIA  k-pop  ...    -2.373       0.0626   89.994
# 1  4ura3429lz6lq6xs5itaoqiyi    CHUNG HA  k-pop  ...    -2.526       0.0445  101.850
# 2  4ura3429lz6lq6xs5itaoqiyi  Red Velvet  k-pop  ...    -3.229       0.0317  150.059
# 3  4ura3429lz6lq6xs5itaoqiyi    (G)I-DLE  k-pop  ...    -3.315       0.0648   92.037
# 4  4ura3429lz6lq6xs5itaoqiyi    (G)I-DLE  k-pop  ...    -3.139       0.0362  120.021
#
# [5 rows x 11 columns]
# genre-type:  electropop  and length:  5674
#                       user_id              artist  ... speechiness    tempo
# 0  4ura3429lz6lq6xs5itaoqiyi       Billie Eilish  ...      0.0482  120.033
# 1  4ura3429lz6lq6xs5itaoqiyi          Kreayshawn  ...      0.0683   77.508
# 2                 1263232932  The Japanese House  ...      0.0286   94.054
# 3                 1263232932                SOHN  ...      0.0498  180.038
# 4                 1263232932  The Japanese House  ...      0.1170  149.938
#
# [5 rows x 11 columns]
# genre-type:  alt z  and length:  15451
#                       user_id            artist  ... speechiness    tempo
# 0  4ura3429lz6lq6xs5itaoqiyi  Melanie Martinez  ...      0.0400   98.020
# 1                 1263232932           mxmtoon  ...      0.1340  145.091
# 2                 1263232932           mxmtoon  ...      0.1340  145.091
# 3                 1263232932          Cavetown  ...      0.0407  130.041
# 4                 1263232932           mxmtoon  ...      0.0281  101.909
#
# [5 rows x 11 columns]
# genre-type:  dance pop  and length:  70354
#                       user_id           artist  ... speechiness    tempo
# 0  4ura3429lz6lq6xs5itaoqiyi           MARINA  ...      0.0349  121.202
# 1  4ura3429lz6lq6xs5itaoqiyi         Doja Cat  ...      0.0661  170.037
# 2  4ura3429lz6lq6xs5itaoqiyi          Beyoncé  ...      0.3170  146.092
# 3  4ura3429lz6lq6xs5itaoqiyi         Doja Cat  ...      0.0921  131.030
# 4  4ura3429lz6lq6xs5itaoqiyi  Destiny's Child  ...      0.0637  119.011
#
# [5 rows x 11 columns]
# genre-type:  pop  and length:  14058
#                       user_id         artist  ... speechiness    tempo
# 0  4ura3429lz6lq6xs5itaoqiyi  Ariana Grande  ...      0.3340  140.048
# 1  4ura3429lz6lq6xs5itaoqiyi  Ariana Grande  ...      0.4610  190.097
# 2  4ura3429lz6lq6xs5itaoqiyi  Ariana Grande  ...      0.1530  103.008
# 3  4ura3429lz6lq6xs5itaoqiyi   Taylor Swift  ...      0.0540   95.997
# 4                 1263232932  Ariana Grande  ...      0.0364   62.520
#
# [5 rows x 11 columns]

# %%
import numpy as np
import scipy.linalg as la
# using mahalanobis for multivariate outlier detection
def mahalanobis(x=None, data=None, inv_covmat=None):
    """Compute the Mahalanobis Distance between each row of x and the data  
    x    : vector or matrix of data with, say, p columns.
    data : ndarray of the distribution from which Mahalanobis distance of each observation of x is to be computed.
    cov  : covariance matrix (p x p) of the distribution. If None, will be computed from data.
    """
    x_minus_mu = x - np.mean(data)
    if np.all(inv_covmat == None):
        cov = np.cov(data.values.T)
        inv_covmat = la.inv(cov)
    left_term = np.dot(x_minus_mu, inv_covmat)
    mahal = np.dot(left_term, x_minus_mu.T)
    if(len(x.shape) == 1):
        return mahal
    else:
        return mahal.diagonal()

# %%
# data now is ready to be analyzed seperately
from collections import defaultdict
from scipy.stats import chi2


del_data_indexes = defaultdict(list)

# numerical columns
num_columns = ['popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'loudness', 'speechiness', 'tempo']
newLength = 0
for key in data.keys():
    mhList = []
    # for data analysis
    cov = np.cov(data[key][num_columns].values.T)
    inv_covmat = la.inv(cov)
    for i in range(len(data[key])):
        row = data[key].iloc[i,:]
        mh = mahalanobis(x=row[num_columns], data=data[key][num_columns], inv_covmat=inv_covmat)
        mhList.append(mh)
    data[key]['mahala'] = mhList
    #chi^2 value: critical value at a 0.01 significance level and 2 degrees of freedom
    data[key]['p_value'] = 1 - chi2.cdf(data[key]['mahala'], 2)
    print('for key=%s, original rows=%d ==> removed rows=%d'%(key,len(data[key]), len(data[key].loc[data[key].p_value < 0.01])))
    data[key] = data[key].loc[data[key].p_value >= 0.01] # must be above this chi^2
    newLength += len(data[key])
# Out:
# for key=k-pop, original rows=1903 ==> removed rows=690
# for key=electropop, original rows=3985 ==> removed rows=1338
# for key=alt z, original rows=11229 ==> removed rows=3653
# for key=dance pop, original rows=70354 ==> removed rows=20580
# for key=pop, original rows=14058 ==> removed rows=4138
# for key=canadian pop, original rows=3465 ==> removed rows=1002
# for key=lo-fi beats, original rows=7839 ==> removed rows=2220
# for key=chill r&b, original rows=2621 ==> removed rows=640
# for key=adult standards, original rows=15923 ==> removed rows=4467
# for key=acoustic pop, original rows=4788 ==> removed rows=1280
# for key=neo mellow, original rows=2071 ==> removed rows=549
# for key=alternative rock, original rows=11957 ==> removed rows=3424
# for key=alternative hip hop, original rows=9713 ==> removed rows=2920
# for key=indie rock, original rows=3374 ==> removed rows=905
# for key=art pop, original rows=4131 ==> removed rows=1147
# for key=ambient, original rows=1927 ==> removed rows=530
# for key=bedroom pop, original rows=2695 ==> removed rows=787
# for key=chillhop, original rows=17951 ==> removed rows=4937
# for key=art rock, original rows=2607 ==> removed rows=732
# for key=emo, original rows=1405 ==> removed rows=387
# for key=alternative r&b, original rows=15571 ==> removed rows=4242
# for key=hip hop, original rows=10616 ==> removed rows=3060
# for key=conscious hip hop, original rows=5404 ==> removed rows=1509
# for key=pop rap, original rows=2055 ==> removed rows=575
# for key=downtempo, original rows=1697 ==> removed rows=453
# for key=folk-pop, original rows=4389 ==> removed rows=1220
# for key=permanent wave, original rows=1794 ==> removed rows=475
# for key=chamber pop, original rows=1446 ==> removed rows=358
# for key=baroque pop, original rows=2691 ==> removed rows=747
# for key=alternative dance, original rows=8991 ==> removed rows=2656
# for key=future funk, original rows=1190 ==> removed rows=335
# for key=alternative country, original rows=2012 ==> removed rows=563
# for key=chillwave, original rows=3227 ==> removed rows=901
# for key=gauze pop, original rows=1141 ==> removed rows=300
# for key=alternative metal, original rows=12924 ==> removed rows=3858
# for key=australian pop, original rows=1838 ==> removed rows=508
# for key=modern alternative rock, original rows=3164 ==> removed rows=889
# for key=indie pop, original rows=4216 ==> removed rows=1168
# for key=canadian hip hop, original rows=5471 ==> removed rows=1601
# for key=classic rock, original rows=6598 ==> removed rows=1798
# for key=beatlesque, original rows=1226 ==> removed rows=353
# for key=indie folk, original rows=4111 ==> removed rows=1057
# for key=canadian indie, original rows=1509 ==> removed rows=398
# for key=album rock, original rows=17422 ==> removed rows=4979
# for key=bow pop, original rows=1716 ==> removed rows=471
# for key=background music, original rows=1603 ==> removed rows=439
# for key=compositional ambient, original rows=1136 ==> removed rows=297
# for key=electronica, original rows=1102 ==> removed rows=308
# for key=brooklyn indie, original rows=1272 ==> removed rows=393
# for key=eau claire indie, original rows=1026 ==> removed rows=253
# for key=funk, original rows=2080 ==> removed rows=594
# for key=arkansas country, original rows=1070 ==> removed rows=277
# for key=british singer-songwriter, original rows=1115 ==> removed rows=280
# for key=indie soul, original rows=2191 ==> removed rows=658
# for key=deep house, original rows=5034 ==> removed rows=1426
# for key=bass music, original rows=1157 ==> removed rows=334
# for key=canadian electronic, original rows=2912 ==> removed rows=822
# for key=modern rock, original rows=3254 ==> removed rows=927
# for key=indie poptimism, original rows=2018 ==> removed rows=615
# for key=chillstep, original rows=1450 ==> removed rows=383
# for key=acid rock, original rows=1502 ==> removed rows=401
# for key=disco, original rows=2246 ==> removed rows=668
# for key=soundtrack, original rows=1333 ==> removed rows=392
# for key=brill building pop, original rows=1695 ==> removed rows=473
# for key=australian indie, original rows=1080 ==> removed rows=315
# for key=australian hip hop, original rows=1509 ==> removed rows=422
# for key=country rap, original rows=1035 ==> removed rows=283
# for key=canadian contemporary r&b, original rows=3325 ==> removed rows=883
# for key=chicago rap, original rows=6724 ==> removed rows=1913
# for key=rap, original rows=2485 ==> removed rows=661
# for key=cali rap, original rows=3988 ==> removed rows=1140
# for key=big room, original rows=9832 ==> removed rows=2712
# for key=colombian pop, original rows=2206 ==> removed rows=639
# for key=german dance, original rows=1486 ==> removed rows=463
# for key=german pop, original rows=1313 ==> removed rows=363
# for key=edm, original rows=13520 ==> removed rows=3839
# for key=brooklyn drill, original rows=2900 ==> removed rows=844
# for key=latin, original rows=9147 ==> removed rows=2609
# for key=atl hip hop, original rows=12307 ==> removed rows=3611
# for key=florida rap, original rows=1402 ==> removed rows=392
# for key=baton rouge rap, original rows=1343 ==> removed rows=412
# for key=houston rap, original rows=1017 ==> removed rows=270
# for key=pop r&b, original rows=1091 ==> removed rows=325
# for key=detroit hip hop, original rows=2415 ==> removed rows=667
# for key=north carolina hip hop, original rows=1397 ==> removed rows=393
# for key=contemporary country, original rows=6385 ==> removed rows=1894
# for key=latin pop, original rows=1448 ==> removed rows=440
# for key=boy band, original rows=3550 ==> removed rows=1003
# for key=afrofuturism, original rows=1276 ==> removed rows=363
# for key=indie anthem-folk, original rows=1938 ==> removed rows=514
# for key=afro dancehall, original rows=1402 ==> removed rows=442
# for key=melodic rap, original rows=6100 ==> removed rows=1709
# for key=escape room, original rows=1802 ==> removed rows=542
# for key=meme rap, original rows=1042 ==> removed rows=309
# for key=indie r&b, original rows=1039 ==> removed rows=271
# for key=sad rap, original rows=1694 ==> removed rows=442
# for key=bass house, original rows=5657 ==> removed rows=1595
# for key=ccm, original rows=11040 ==> removed rows=3090
# for key=indie cafe pop, original rows=2199 ==> removed rows=568
# for key=dancehall, original rows=2081 ==> removed rows=580
# for key=background piano, original rows=1012 ==> removed rows=299
# for key=deep underground hip hop, original rows=1344 ==> removed rows=399
# for key=blues rock, original rows=1033 ==> removed rows=300
# for key=deep groove house, original rows=7099 ==> removed rows=2033
# for key=australian dance, original rows=3068 ==> removed rows=850
# for key=electro house, original rows=3489 ==> removed rows=1022
# for key=brazilian edm, original rows=2326 ==> removed rows=657
# for key=belgian edm, original rows=1819 ==> removed rows=527
# for key=brostep, original rows=3810 ==> removed rows=1062
# for key=bassline, original rows=1075 ==> removed rows=323
# for key=bass trap, original rows=6069 ==> removed rows=1718
# for key=tropical house, original rows=1310 ==> removed rows=386
# for key=emo rap, original rows=3988 ==> removed rows=1068
# for key=dubstep, original rows=1479 ==> removed rows=403
# for key=british soul, original rows=1874 ==> removed rows=528
# for key=east coast hip hop, original rows=5394 ==> removed rows=1606
# for key=europop, original rows=1096 ==> removed rows=320
# for key=g funk, original rows=1733 ==> removed rows=500
# for key=classic soul, original rows=2410 ==> removed rows=708
# for key=bebop, original rows=1231 ==> removed rows=356
# for key=complextro, original rows=1097 ==> removed rows=301
# for key=dark trap, original rows=3276 ==> removed rows=893
# for key=uk hip hop, original rows=1483 ==> removed rows=439
# for key=gangster rap, original rows=1985 ==> removed rows=582
# for key=dfw rap, original rows=1636 ==> removed rows=434
# for key=afropop, original rows=1057 ==> removed rows=302
# for key=afroswing, original rows=1819 ==> removed rows=529
# for key=uk alternative hip hop, original rows=2490 ==> removed rows=743
# for key=grime, original rows=4993 ==> removed rows=1499
# for key=christian hip hop, original rows=17557 ==> removed rows=5039
# for key=la pop, original rows=1021 ==> removed rows=273
# for key=aussietronica, original rows=1383 ==> removed rows=382
# for key=birmingham grime, original rows=1009 ==> removed rows=300
# for key=drum and bass, original rows=2175 ==> removed rows=637
# for key=new french touch, original rows=1180 ==> removed rows=326
# for key=deep tropical house, original rows=2395 ==> removed rows=715
# for key=pop edm, original rows=2738 ==> removed rows=774
# for key=gaming edm, original rows=2247 ==> removed rows=652
# for key=house, original rows=1450 ==> removed rows=402
# for key=deep euro house, original rows=1109 ==> removed rows=312
# for key=afrobeat, original rows=1014 ==> removed rows=294
# for key=future bass, original rows=2384 ==> removed rows=681
# for key=japanese chillhop, original rows=1056 ==> removed rows=280
# for key=focus beats, original rows=6996 ==> removed rows=1801
# for key=classical, original rows=2119 ==> removed rows=556
# for key=deep disco house, original rows=1281 ==> removed rows=329
# for key=dutch edm, original rows=1779 ==> removed rows=523
# for key=country, original rows=1862 ==> removed rows=527
# for key=traprun, original rows=1649 ==> removed rows=511
# for key=slap house, original rows=3214 ==> removed rows=962
# for key=anthem worship, original rows=11161 ==> removed rows=3139
# for key=bachata, original rows=1624 ==> removed rows=513
# for key=gospel, original rows=2081 ==> removed rows=584
# for key=glee club, original rows=7810 ==> removed rows=2368
# for key=lo-fi cover, original rows=1111 ==> removed rows=314
# for key=broadway, original rows=1083 ==> removed rows=320
# for key=acoustic blues, original rows=1008 ==> removed rows=287
# for key=groove room, original rows=1886 ==> removed rows=544

# %%
print('Original length: ', len(users_info))
print('New Length after mahalanobis outlier removal: ', newLength)
# Out:
# Original length:  646206
# New Length after mahalanobis outlier removal:  456873

# %%
# normalize the data
norm = {'popularity': 100, 'loudness': 60, 'tempo': 200} # 200 for tempo because of edm type music with faster beats
for key in data.keys():
    for attr in norm:
        data[key][attr] = data[key][attr] / norm[attr] # normalize each attribute

# %%
# get cluster centers
cluster_centers = {}

for key in data.keys():
    cluster_centers[key] = np.mean(data[key][num_columns]).tolist()

# %%
# combine all data
all_data = pd.concat([data[k] for k in data.keys()]) # join all data
all_data = all_data.sample(frac=1).reset_index(drop=True) # shuffle data and reset index

# %%
threshold = round(len(all_data)*0.8)

# train
x_train = all_data[num_columns].iloc[:threshold,:]
y_train = all_data['genre'].iloc[:threshold,:]
# test
x_test = all_data[num_columns].iloc[threshold:,:]
y_test = all_data['genre'].iloc[threshold:,:]

# def getAccuracy(centroids):
#     accuracy = 0
#     for i in range(len(x_test)):
#         minDist = float('inf')
#         row = x_test.iloc[i,:]
#         for center in centroids:
#             distance = np.linalg.norm(np.array(row) - np.array(center))
#             if(distance > minDist):
#                 minDist =

# %%
# make true labels
keys = {}
nextVal = 0
true_labels = []
for i in range(len(all_data)):
    g = str(all_data.loc[i,['genre']][0])
    # print(g)
    if g not in keys:
        keys[g] = nextVal
        nextVal += 1
    true_labels.append(keys[g])
all_data['true_labels'] = true_labels

# %%
#this is line seperator
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)
pca_result = pca.fit_transform(all_data[num_columns].values)

all_data['pca-one'] = pca_result[:,0]
all_data['pca-two'] = pca_result[:,1]
all_data['pca-three'] = pca_result[:,2]

print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.4804907  0.32300985 0.09859109]

# %% [markdown]
# # new starting point due to slow runtime....

# %%
# # export data
# print('starting to export data...')
# all_data.to_csv('all_clustering_data.csv.zip', compression='zip')
# print('done exporting!')

# import data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

all_data = pd.read_csv('all_clustering_data.csv.zip', compression='zip')
print('done importing!')
true_labels = all_data['true_labels']
cols = ['pca-one','pca-two','pca-three']
# Out:
# starting to export data...

# %%
# find averages for each genre
sumKeys = {} # key=GENRE, value=(sum,count)
for i in range(len(all_data)):
    row = all_data[cols].iloc[i,:].tolist()
    g = all_data.loc[i,['genre']][0]
    if(g not in sumKeys):
        sumKeys[g] = [np.array(row),1]
    else:
        sumKeys[g][0] += np.array(row) # element wise addition
        sumKeys[g][1] += 1
    if(i % 1000==0):
        print('at row: ', i)
averages = [sumKeys[k][0]/sumKeys[k][1] for k in sumKeys.keys()]
print(averages)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-670aadd5efec> in <module>
#       2 sumKeys = {} # key=GENRE, value=(sum,count)
#       3 for i in range(len(all_data)):
# ----> 4     row = all_data[num_columns].iloc[i,:].tolist()
#       5     g = str(all_data.loc[i,['genre']][0])
#       6     if(g not in sumKeys):
#
# KeyboardInterrupt:

# %%
print(type(averages[0]))

# %%
k_means_kwargs = {
    'init': nd.array(averages), 
    'n_init':10, 
    'max_iter':300, 
    'random_state':42
}

k = len(sumKeys.keys()) # unique centers
# run K Means
print('Running KMEANS:')
kmeans = KMeans(n_clusters=k, **k_means_kwargs)
kmeans.fit(all_data[cols])
print('lowest SSE: ', kmeans.inertia_)
print('silhouette score: ', silhouette_score(all_data[cols], kmeans.labels_, metric='euclidean',))
ari_kmeans = adjusted_rand_score(true_labels, kmeans.labels_)
print('Adjusted Rand Index: ', ari_kmeans)
all_data['labels_graph'] = kmeans.labels_



# PLOT THIS BAD BOY


#Getting the Centroids
centroids = kmeans.cluster_centers_
u_labels = np.unique(kmeans.labels_)

#plotting the results:
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in u_labels:
    ax.scatter(all_data['pca-one'].loc[all_data['labels_graph'] == i], all_data['pca-two'].loc[all_data['labels_graph'] == i], all_data['pca-three'].loc[all_data['labels_graph'] == i], label=i)
ax.scatter(centroids[:,0], centroids[:,1], centroids[:,2], s = 80, color = 'red', marker='x')
ax.legend()
plt.show()

# %%
print('Running DBSCAN:')
dbscan = DBSCAN(eps=0.25) # maximum distance between two samples
dbscan.fit(all_data[cols])
print('silhouette score: ', silhouette_score(all_data[cols], dbscan.labels_, metric='euclidean'))
ari_dbscan = adjusted_rand_score(true_labels, dbscan.labels_)
print('Adjusted Rand Index: ', ari_dbscan)
all_data['labels_graph'] = dbscan.labels_



#Getting the Centroids
centroids = dbscan.cluster_centers_
u_labels = np.unique(dbscan.labels_)

#plotting the results:
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in u_labels:
    ax.scatter(all_data['pca-one'].loc[all_data['labels_graph'] == i], all_data['pca-two'].loc[all_data['labels_graph'] == i], all_data['pca-three'].loc[all_data['labels_graph'] == i], label=i)
ax.scatter(centroids[:,0], centroids[:,1], centroids[:,2], s = 80, color = 'red', marker='x')
ax.legend()
plt.show()

# %% [markdown]
# ### The rest is optional, not really necessary...Pehaps just for ARI and other metrics

# %%
# import data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


all_data = pd.read_csv('all_clustering_data.csv.zip', compression='zip')
print('done importing!')
true_labels = all_data['true_labels']

num_columns = ['popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'loudness', 'speechiness', 'tempo']
# Out:
# done importing!

# %%
# find averages for each genre
cluster_centers = {} # key=GENRE, value=(sum,count)
for i in range(len(all_data)):
    row = all_data[num_columns].iloc[i,:].to_numpy()
    g = all_data.loc[i,['genre']][0]
    if(g not in cluster_centers):
        cluster_centers[g] = [row,1]
    else:
        cluster_centers[g][0] += row # element wise addition
        cluster_centers[g][1] += 1
    if(i % 1000==0):
        print('at row: ', i)
# Out:
# at row:  0
# at row:  1000
# at row:  2000
# at row:  3000
# at row:  4000
# at row:  5000
# at row:  6000
# at row:  7000
# at row:  8000
# at row:  9000
# at row:  10000
# at row:  11000
# at row:  12000
# at row:  13000
# at row:  14000
# at row:  15000
# at row:  16000
# at row:  17000
# at row:  18000
# at row:  19000
# at row:  20000
# at row:  21000
# at row:  22000
# at row:  23000
# at row:  24000
# at row:  25000
# at row:  26000
# at row:  27000
# at row:  28000
# at row:  29000
# at row:  30000
# at row:  31000
# at row:  32000
# at row:  33000
# at row:  34000
# at row:  35000
# at row:  36000
# at row:  37000
# at row:  38000
# at row:  39000
# at row:  40000
# at row:  41000
# at row:  42000
# at row:  43000
# at row:  44000
# at row:  45000
# at row:  46000
# at row:  47000
# at row:  48000
# at row:  49000
# at row:  50000
# at row:  51000
# at row:  52000
# at row:  53000
# at row:  54000
# at row:  55000
# at row:  56000
# at row:  57000
# at row:  58000
# at row:  59000
# at row:  60000
# at row:  61000
# at row:  62000
# at row:  63000
# at row:  64000
# at row:  65000
# at row:  66000
# at row:  67000
# at row:  68000
# at row:  69000
# at row:  70000
# at row:  71000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6e39386c2a3a> in <module>
#       3 for i in range(len(all_data)):
#       4     row = all_data[num_columns].iloc[i,:].to_numpy()
# ----> 5     g = all_data.loc[i,['genre']][0]
#       6     if(g not in cluster_centers):
#       7         cluster_centers[g] = [row,1]
#
# KeyboardInterrupt:

# %%
# from kneed import KneeLocator
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score


scaler = StandardScaler()
scaled_features = scaler.fit_transform(all_data[num_columns]) # makes mean of 0 and stdev of 1
# scaled_features = df_subset[feat_cols] # normalized

# %%
centers = [cluster_centers[k][0]/cluster_centers[k][1] for k in cluster_centers.keys()]

k_means_kwargs = {
    'init':np.array(centers), 
    'n_init':10, 
    'max_iter':300, 
    'random_state':42
}

k = len(cluster_centers.keys()) # unique centers
# run K Means
print('Running KMEANS:')
kmeans = KMeans(n_clusters=k, **k_means_kwargs)
kmeans.fit(scaled_features)
print('lowest SSE: ', kmeans.inertia_)
new_centers = kmeans.cluster_centers_
print('silhouette score: ', silhouette_score(scaled_features, kmeans.labels_, metric='euclidean',))
ari_kmeans = adjusted_rand_score(true_labels, kmeans.labels_)
print('Adjusted Rand Index: ', ari_kmeans)

# %%
print('Running DBSCAN:')
dbscan = DBSCAN(eps=0.3)
dbscan.fit(scaled_features)
print('silhouette score: ', silhouette_score(scaled_features, dbscan.labels_, metric='euclidean'))
ari_dbscan = adjusted_rand_score(true_labels, dbscan.labels_)
print('Adjusted Rand Index: ', ari_dbscan)
